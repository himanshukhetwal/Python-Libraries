# %% [markdown]
# # Distribution PLot

# %% [raw]
# we use distribution plots to visualize the distribution of quantitative data
#
# Lets discuss some plots that allow us to visulaize the distribution of a data set. These plots are:
#
# distplot/histplot
# jointplot
# pairplot
# rugplot

# %%
import seaborn as sns # seaborn has automatically have some datasets  
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
 df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
# Creation of Distplot
sns.histplot(df['total_bill'],bins=12,kde=True) #bins tells the no. of bars you want in ur graph
#kde tells the skeweness of ur data like left skewed or right skewed
#kde is the line u are seeing in graph
#defailt value of bin is 20 (when we do not use bin)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# creation of subplots 
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins=20,kde=True) 
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# Joint Plot
# when we compare two values like total_bills and tip then we use joint plot
sns.jointplot(x='total_bill', y ='tip',data=df)

# %%
# Pair PLot
sns.pairplot(df,hue='sex',palette='rainbow') # when we gave whole data fram it comapred 3 things total_bill,tips and size as they all are numeric values
# hue means dividing data categorywise

# %%
# Rug Plot
sns.rugplot(df)
# Out:
# <Axes: >
